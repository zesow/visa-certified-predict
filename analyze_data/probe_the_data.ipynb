# %%
import csv
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../rawdata/h1b_train.csv',header=0)

# %%
data
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0           1349742            CERTIFIED
# 1            789205            CERTIFIED
# 2           1617140            CERTIFIED
# 3           2757905            CERTIFIED
# 4           1127948            WITHDRAWN
# 5            693102               DENIED
# 6           2662510            CERTIFIED
# 7            636434            CERTIFIED
# 8           2265757            CERTIFIED
# 9           2927315            CERTIFIED
# 10          1696111            CERTIFIED
# 11          2042418            CERTIFIED
# 12          2556938            CERTIFIED
# 13          1620167            CERTIFIED
# 14          2066155            CERTIFIED
# 15          2836033            CERTIFIED
# 16          1649897            CERTIFIED
# 17           734416            CERTIFIED
# 18          2959714            CERTIFIED
# 19          1498142            CERTIFIED
# 20            98397            CERTIFIED
# 21          2196173            CERTIFIED
# ...

# %% [markdown]
# ## 비자 발급 결과에는 5가지가 있다.

# %%
status_set = set(data.CASE_STATUS)
status_set
# Out:
# {'CERTIFIED',
#  'CERTIFIED-WITHDRAWN',
#  'DENIED',
#  'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED',
#  'REJECTED',
#  'WITHDRAWN',
#  nan}

# %% [markdown]
# ## 직업군은 21만개

# %%
job_title_set = set(data.JOB_TITLE)
len(job_title_set)
# Out:
# 209569

# %% [markdown]
# ## 회사이름은 18만개

# %%
cname_set = set(data.EMPLOYER_NAME)
len(cname_set)
# Out:
# 186262

# %% [markdown]
# ## 회사위치 갯수

# %%
worksite_set = set(data.WORKSITE)
len(worksite_set)
# Out:
# 15600

# %%
##

# %%
soc_name_set = set(data.SOC_NAME)
len(soc_name_set)
# Out:
# 1880
